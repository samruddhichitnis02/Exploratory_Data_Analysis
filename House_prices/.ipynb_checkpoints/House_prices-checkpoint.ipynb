# %%
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %% [markdown]
# # Checking for Null Values

# %%
fig, ax = plt.subplots(figsize = (10, 6))
sb.heatmap(data.isna(),
           cbar = False,
           yticklabels = False,
           cmap = 'Blues')
plt.show()

# %% [markdown]
# removing  Id and the features with 30% or less data.

# %%
len(data['Id'].unique())
# Out:
# 1460

# %%
data.drop(['Id'], axis = 1, inplace = True)

# %%
dataset = data[[column for column in data if data[column].count() / len(data) >= 0.3]]

# %%
dataset.sample(2)
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 169          20       RL          NaN    16669   Pave      IR1         Lvl
# 838          20       RL         75.0     9525   Pave      Reg         Lvl
#
#     Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 169    AllPub    Corner       Gtl  ...             0         0           0
# 838    AllPub    Inside       Gtl  ...             0         0           0
#
#     PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 169        0       0       1    2006        WD         Normal    228000
# 838        0       0       6    2008        WD         Normal    144000
#
# [2 rows x 76 columns]

# %%
print("List of dropped columns:", end=" ")
for c in data.columns:
    if c not in dataset.columns:
        print(c, end=", ")
# Out:
# List of dropped columns: Alley, PoolQC, Fence, MiscFeature,

# %%
fig, ax = plt.subplots(figsize = (10, 6))
sb.heatmap(dataset.isna(),
           cbar = False,
           yticklabels = False,
           cmap = 'Blues')
plt.show()

# %% [markdown]
# # Checking the distribution of output

# %%
print(dataset['SalePrice'].describe())
plt.figure(figsize=(6, 5))
sb.distplot(dataset['SalePrice'], color='b', bins=100, hist_kws={'alpha': 0.4})
plt.show()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# # Different data types present in data

# %%
pd.DataFrame(dataset.dtypes.unique()).T
# Out:
#        0       1        2
# 0  int64  object  float64

# %%
dataset.hist(figsize=(16, 20), bins=50, xlabelsize=10, ylabelsize=8)
plt.show()

# %% [markdown]
# # Finding the Correlation between the features and label

# %%
data_corr = dataset.corr()['SalePrice'][:-1] 
correlation = data_corr[abs(data_corr) >= 0.5].sort_values(ascending = False)

# %%
print("There is {} strongly correlated values with SalePrice:\n{}".format(len(correlation), correlation))
# Out:
# There is 10 strongly correlated values with SalePrice:
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# Name: SalePrice, dtype: float64

# %% [markdown]
# # Feature to feature relationship

# %%
# We already examined SalePrice correlations
corr = dataset.drop('SalePrice', axis = 1).corr()
plt.figure(figsize=(15, 10))

sb.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)],
           cmap = '',
           vmax = 1.0,
           vmin = -1.0,
           linewidths = 0.1,
           annot = True,
           annot_kws = {"size": 10},
           square = True);

# %%
quantitative_features_list = ['LotFrontage', 'LotArea', 'MasVnrArea', 
                              'BsmtFinSF1', 'BsmtFinSF2', 'TotalBsmtSF', 
                              '1stFlrSF','2ndFlrSF', 'LowQualFinSF', 
                              'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 
                              'FullBath', 'HalfBath','BedroomAbvGr', 
                              'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
                              'GarageCars', 'GarageArea', 'WoodDeckSF', 
                              'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 
                              'ScreenPorch', 'PoolArea', 'MiscVal', 'SalePrice']
df_quantitative_values = data[quantitative_features_list]
df_quantitative_values.head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  TotalBsmtSF  \
# 0         65.0     8450       196.0         706           0          856
# 1         80.0     9600         0.0         978           0         1262
# 2         68.0    11250       162.0         486           0          920
# 3         60.0     9550         0.0         216           0          756
# 4         84.0    14260       350.0         655           0         1145
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  ...  GarageCars  GarageArea  \
# 0       856       854             0       1710  ...           2         548
# 1      1262         0             0       1262  ...           2         460
# 2       920       866             0       1786  ...           2         608
# 3       961       756             0       1717  ...           3         642
# 4      1145      1053             0       2198  ...           3         836
#
# ...

# %%
features_to_analyse = [x for x in quantitative_features_list if x in correlation]
features_to_analyse.append('SalePrice')

# %% [markdown]
# Distribution of quantitative features which have good correlation with SalesPrice

# %%
fig, ax = plt.subplots(2, 4, figsize = (18, 12))
for i, ax in enumerate(fig.axes):
    if i< len(features_to_analyse) -1: #-1 since it also has label('SalePrice')
        sb.regplot(x = features_to_analyse[i],
                   y = 'SalePrice',
                   data = dataset[features_to_analyse],
                   ax = ax)

# %% [markdown]
# We can see that features such as TotalBsmtSF, 1stFlrSF, GrLivArea have a big spread
